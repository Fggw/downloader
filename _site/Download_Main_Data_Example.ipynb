# %% [markdown]
# ## Main Data Aggregation Script
#
# #### Farewell, Gober, Green, Welborn

# %% [markdown]
# We ran the downloader as command line script, but this is an example of how it *could* be used from a notebook. We cleaned out data we didn't need any more in later cleaning stages after making different decisions about how to collate in crime and sanitation data, as well. Running `main` with `export=True` writes a file called `DOWNLOADED_DATA.csv` to the current working directory.
#
# To keep the logic clean while running the script, we left the code in the python module `download.py`. The downloaded data that we worked with is available via Dropbox [here](http://www.dropbox.com).

# %%
import download
import datetime

# %%
sd = datetime.datetime.strptime("2016-11-15", "%Y-%m-%d")

# %%
dat = download.main(sd)
# Out:
# Fetching data beginning 2016-11-15.
# 909 records received. Finding businesses...
# Succeeded!
# Succeeded!
# Succeeded!
# RECEIVED 2860 business details
# Succeeded!
# Succeeded!
# /usr/local/lib/python2.7/site-packages/numpy/lib/arraysetops.py:200: FutureWarning: numpy not_equal will not check object identity in the future. The comparison did not return the same result as suggested by the identity (`is`)) and will change.
#   flag = np.concatenate(([True], aux[1:] != aux[:-1]))

# %%
dat.head()
# Out:
#                      dba_name         facility_type inspection_date  \
# 0                   POKIOLOGY            Restaurant      2016-11-17
# 1         BOP BAR KOREAN FOOD  Mobile Food Preparer      2016-12-05
# 2                   POKIOLOGY            Restaurant      2016-11-29
# 3  Subway Sandwiches & Salads            Restaurant      2016-11-23
# 4       THE CLIPPER/ CC FERNS            Restaurant      2016-12-09
#
#            inspection_type inspection_id  \
# 0                Complaint       1975631
# 1                  Canvass       1976467
# 2  Complaint Re-Inspection       1976144
# 3                  Canvass       1975944
# 4    Canvass Re-Inspection       1976799
#
#                                           violations   latitude license_  \
# 0  29. PREVIOUS MINOR VIOLATION(S) CORRECTED 7-42...  41.965435  2483500
# 1                                                NaN        NaN  2438187
# 2  29. PREVIOUS MINOR VIOLATION(S) CORRECTED 7-42...  41.965435  2483500
# ...
